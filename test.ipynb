# %%
import pandas as pd
import numpy as np
import requests
import swifter

# %%
# Read in 1.2 Million Spotify Songs dataset
spotify_1m = pd.read_csv('./Resources/tracks_features.csv')

# %%
# Strip brackets and single quotes from artist name
spotify_1m['artist'] = spotify_1m['artists'].str.strip("[']")

# Preview dataframe
spotify_1m.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# 1  ['2d0hyoQ5ynDBnkvAbJKORj']             2            1      True
# 2  ['2d0hyoQ5ynDBnkvAbJKORj']             3            1     False
# 3  ['2d0hyoQ5ynDBnkvAbJKORj']             4            1      True
# 4  ['2d0hyoQ5ynDBnkvAbJKORj']             5            1     False
#
#    danceability  ...  acousticness  instrumentalness  liveness  valence  \
# 0         0.470  ...       0.02610          0.000011    0.3560    0.503
# 1         0.599  ...       0.01290          0.000071    0.1550    0.489
# 2         0.315  ...       0.02340          0.000002    0.1220    0.370
# 3         0.440  ...       0.16300          0.000004    0.1210    0.574
# 4         0.426  ...       0.00162          0.105000    0.0789    0.539
#
#      tempo  duration_ms  time_signature  year  release_date  \
# 0  117.906       210133             4.0  1999    1999-11-02
# 1  103.680       206200             4.0  1999    1999-11-02
# 2  149.749       298893             4.0  1999    1999-11-02
# 3   96.752       213640             4.0  1999    1999-11-02
# 4  127.059       205600             4.0  1999    1999-11-02
#
#                      artist
# 0  Rage Against The Machine
# 1  Rage Against The Machine
# 2  Rage Against The Machine
# 3  Rage Against The Machine
# 4  Rage Against The Machine
#
# [5 rows x 25 columns]

# %%
# Read in Billboard Top 100 dataset
df = pd.read_csv('./Resources/charts.csv')

# Convert date column to date type
df['date'] = pd.to_datetime(df['date'])
# Create new column for year
df['year'] = df['date'].dt.year
# Remove special characters from artist and song name
df['artist'] = df['artist'].str.replace(r"\(.*\)","")
# df['song'] = df['song'].str.replace(r"\(.*\)","")

df['song'] = df['song'].str.replace(".","") \
                        .str.replace("\"", "") \
                        .str.replace(",", "") \
                        .str.replace("!", "")


# Create new column showing number of weeks in #1 spot (if exists)
df['weeks-at-no1'] = df[df['rank']==1].groupby(['song', 'artist', 'rank'], as_index=False).count()['date']

# Remove single quotes/apostrophes from song names
df['song'] = df['song'].str.replace("'", "")

# Preview dataframe
df.head()
# Out:
#         date  rank           song                         artist  last-week  \
# 0 2021-11-06     1     Easy On Me                          Adele        1.0
# 1 2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2 2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3 2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4 2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board  year  weeks-at-no1
# 0          1               3  2021           1.0
# 1          1              16  2021           7.0
# 2          1              14  2021           1.0
# 3          3              19  2021           4.0
# 4          2              18  2021           2.0

# %%
# Create new dataframe of all unique Billboard charting songs
unique_billboard_tracks_df = df.groupby(['song','artist', 'year'], as_index=False).agg({'peak-rank': 'min', 
                                                                                        'weeks-on-board': 'max',
                                                                                        'weeks-at-no1': 'max'})

# Create separate dataframes for each decade
billboard_1960s = unique_billboard_tracks_df[(unique_billboard_tracks_df['year']<1970) & (unique_billboard_tracks_df['year']>=1960)]
billboard_1970s = unique_billboard_tracks_df[(unique_billboard_tracks_df['year']<1980) & (unique_billboard_tracks_df['year']>=1970)]
billboard_1980s = unique_billboard_tracks_df[(unique_billboard_tracks_df['year']<1990) & (unique_billboard_tracks_df['year']>=1980)]
billboard_1990s = unique_billboard_tracks_df[(unique_billboard_tracks_df['year']<2000) & (unique_billboard_tracks_df['year']>=1990)]
billboard_2000s = unique_billboard_tracks_df[(unique_billboard_tracks_df['year']<2010) & (unique_billboard_tracks_df['year']>=2000)]
billboard_2010s = unique_billboard_tracks_df[(unique_billboard_tracks_df['year']<2020) & (unique_billboard_tracks_df['year']>=2010)]
billboard_2020s = unique_billboard_tracks_df[unique_billboard_tracks_df['year']>=2020]

# Create list of dataframes
billboard_dfs = [billboard_1960s, billboard_1970s, billboard_1980s, billboard_1990s, billboard_2000s, billboard_2010s, billboard_2020s]

# Display dataframe
unique_billboard_tracks_df.head()
unique_billboard_tracks_df

# df[(df['artist']=='Beastie Boys') & (df['year']==1986)]
# Out:
#                                                    song        artist  year  \
# 0                                                    #1         Nelly  2001
# 1                                                    #1         Nelly  2002
# 2                                            #1 Dee Jay   Goody Goody  1978
# 3                                              #9 Dream   John Lennon  1974
# 4                                              #9 Dream   John Lennon  1975
# ...                                                 ...           ...   ...
# 36078                                          whoknows         Musiq  2004
# 36079                                         wwwmemory  Alan Jackson  2000
# 36080                                         wwwmemory  Alan Jackson  2001
# 36081  ¿Dònde Està Santa Claus? (Where Is Santa Claus?)    Augie Rios  1958
# 36082  ¿Dònde Està Santa Claus? (Where Is Santa Claus?)    Augie Rios  1959
#
#        peak-rank  weeks-on-board  weeks-at-no1
# 0             22              11           NaN
# 1             22              20           NaN
# 2             82               5           NaN
# 3             58               2           NaN
# 4              9              12           NaN
# ...          ...             ...           ...
# 36078         65              13           NaN
# 36079         45               9           NaN
# 36080         45              15           NaN
# 36081         47               3           NaN
# 36082         47               4           NaN
#
# [36083 rows x 6 columns]

# %%
unique_billboard_tracks_df[unique_billboard_tracks_df['song'].str.contains("\?")]
# Out:
#                                                     song  \
# 105    (If You Let Me Make Love To You Then) Why Cant...
# 172    (Sartorial Eloquence) Dont Ya Wanna Play This ...
# 1269                                           All Good?
# 1270                                           All Good?
# 1935   Any Man Of Mine/Whose Bed Have Your Boots Been...
# ...                                                  ...
# 35432                     You Know I Love You  Dont You?
# 36052                                  homecoming queen?
# 36053                                  homecoming queen?
# 36081   ¿Dònde Està Santa Claus? (Where Is Santa Claus?)
# 36082   ¿Dònde Està Santa Claus? (Where Is Santa Claus?)
#
#                                 artist  year  peak-rank  weeks-on-board  \
# 105                       Ronnie Dyson  1970          8              14
# 172                         Elton John  1980         39              12
# 1269   De La Soul Featuring Chaka Khan  2000         96               2
# 1270   De La Soul Featuring Chaka Khan  2001         96               3
# 1935                      Shania Twain  1995         31              19
# ...                                ...   ...        ...             ...
# 35432                     Howard Jones  1987         17              16
# 36052                 Kelsea Ballerini  2019         82               3
# 36053                 Kelsea Ballerini  2020         65              13
# 36081                       Augie Rios  1958         47               3
# 36082                       Augie Rios  1959         47               4
#
#        weeks-at-no1
# 105             NaN
# 172             NaN
# 1269            NaN
# 1270            NaN
# 1935            NaN
# ...             ...
# 35432           NaN
# 36052           NaN
# 36053           NaN
# 36081           NaN
# 36082           NaN
#
# [253 rows x 6 columns]

# %%
# SPOTIFY API
# Import dependencies for Spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Import Client ID and Client Secret
from config import cid, secret


# Create objects for accessing Spotify API
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Create function to retrieve track ID from Spotify given the artist and song title
def get_track_id(song_title, artist):
    # Select first artist if multiple listed with "Featuring" keyword
    if 'Featuring' in artist:
        artist = artist.split(' Featuring ')[0]
    # Select first artist if multiple listed with "with" keyword
    elif ' with ' in artist:
        artist = artist.split(' with ')[0]
    elif ' With ' in artist:
        artist = artist.split(' With ')[0]
    elif "," in artist:
        artist = artist.split(',')[0]
    # Make API call
    try:
        # Store search results for track with artist and song title as query parameters
        searchResults = sp.search(q=f"artist:{artist} track:{song_title}", type="track")
        # Store track ID
        track_id = searchResults['tracks']['items'][0]['id']
        print(f"{song_title} by {artist}")
        return track_id
    
    # Executes if no match found yet
    except:
        # Check for '&' character
        if ' & ' in artist:
            try:
                # Slice artist name before '&' symbol to get first artist name
                artist = artist.split(' & ')[0]
                # Store search results for track with artist and song title as query parameters
                searchResults = sp.search(q=f"artist:{artist} track:{song_title}", type="track")
                # Store track ID
                track_id = searchResults['tracks']['items'][0]['id']
                print(f"{song_title} by {artist}")
                return track_id
            
            # Executes if still no match found
            except:
                # Print song title and artist for non-match
                print(f'No ID found for {song_title} by {artist}')

# %%
def get_audio_features(uri):
    searchResults = sp.audio_features(uri)
    return searchResults

# %%
song = "Did You Have A Happy Birthday"
artist = "Paul Anka"
# result = sp.search(q=f"artist: {artist} track: {song}", type="track")['tracks']['items'][0]#['id']
result = sp.search(q=f"{artist} {song}", type=["track", "artist"],)['tracks']['items']#[0]['id']
result
# sp.search(q=f"track:{song} artist:{artist}", type='track', limit=1)
# get_track_id(song, artist)
# len(result)
# Out:
# [{'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3rhYtnqug5utE5hEMTRuZl'},
#    'href': 'https://api.spotify.com/v1/albums/3rhYtnqug5utE5hEMTRuZl',
#    'id': '3rhYtnqug5utE5hEMTRuZl',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f4ce5482cb7d519249712290',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f4ce5482cb7d519249712290',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f4ce5482cb7d519249712290',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Paul Anka Sings His Big Ten, Vol. 1',
#    'release_date': '1992-01-17',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:3rhYtnqug5utE5hEMTRuZl'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 160666,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCRB0302624'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2inry9gZX0A8bv2yNPDCtg'},
#   'href': 'https://api.spotify.com/v1/tracks/2inry9gZX0A8bv2yNPDCtg',
#   'id': '2inry9gZX0A8bv2yNPDCtg',
#   'is_local': False,
#   'name': 'Put Your Head On My Shoulder',
#   'popularity': 43,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0867ddb4a4063659a98980513cfacf05da507e86?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:2inry9gZX0A8bv2yNPDCtg'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/68NffwvgGGTB3aDqkbvztJ'},
#    'href': 'https://api.spotify.com/v1/albums/68NffwvgGGTB3aDqkbvztJ',
#    'id': '68NffwvgGGTB3aDqkbvztJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27323e5822ae255ef170c40caf0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0223e5822ae255ef170c40caf0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485123e5822ae255ef170c40caf0',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Sings His Favorites',
#    'release_date': '1966',
#    'release_date_precision': 'year',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:68NffwvgGGTB3aDqkbvztJ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 155080,
#   'explicit': False,
#   'external_ids': {'isrc': 'USRC11602670'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7eqNATKM78MkWP6aHGXHEV'},
#   'href': 'https://api.spotify.com/v1/tracks/7eqNATKM78MkWP6aHGXHEV',
#   'id': '7eqNATKM78MkWP6aHGXHEV',
#   'is_local': False,
#   'name': 'Put Your Head on My Shoulder',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/bec3430010c1b3452628ba145a4ea56989a5c25f?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:7eqNATKM78MkWP6aHGXHEV'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5yekdvOvjZ0Zptw76gpL95'},
#    'href': 'https://api.spotify.com/v1/albums/5yekdvOvjZ0Zptw76gpL95',
#    'id': '5yekdvOvjZ0Zptw76gpL95',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732268471b66f2de42940f5c63',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022268471b66f2de42940f5c63',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512268471b66f2de42940f5c63',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Anka',
#    'release_date': '1974',
#    'release_date_precision': 'year',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:5yekdvOvjZ0Zptw76gpL95'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3UgUTRbDBLMcRCantpTWIe'},
#     'href': 'https://api.spotify.com/v1/artists/3UgUTRbDBLMcRCantpTWIe',
#     'id': '3UgUTRbDBLMcRCantpTWIe',
#     'name': 'Odia Coates',
#     'type': 'artist',
#     'uri': 'spotify:artist:3UgUTRbDBLMcRCantpTWIe'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 156293,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEM38700127'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5PuAFxKmqG72uKyoo11zpQ'},
#   'href': 'https://api.spotify.com/v1/tracks/5PuAFxKmqG72uKyoo11zpQ',
#   'id': '5PuAFxKmqG72uKyoo11zpQ',
#   'is_local': False,
#   'name': "(You're) Having My Baby",
#   'popularity': 50,
#   'preview_url': 'https://p.scdn.co/mp3-preview/6120f74beacaff8e99b6e9848ae290c24b16ee0c?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5PuAFxKmqG72uKyoo11zpQ'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/68NffwvgGGTB3aDqkbvztJ'},
#    'href': 'https://api.spotify.com/v1/albums/68NffwvgGGTB3aDqkbvztJ',
#    'id': '68NffwvgGGTB3aDqkbvztJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27323e5822ae255ef170c40caf0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0223e5822ae255ef170c40caf0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485123e5822ae255ef170c40caf0',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Sings His Favorites',
#    'release_date': '1966',
#    'release_date_precision': 'year',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:68NffwvgGGTB3aDqkbvztJ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 140520,
#   'explicit': False,
#   'external_ids': {'isrc': 'USRC11602669'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2k6qpHJsrKCCyvsHv2cPqR'},
#   'href': 'https://api.spotify.com/v1/tracks/2k6qpHJsrKCCyvsHv2cPqR',
#   'id': '2k6qpHJsrKCCyvsHv2cPqR',
#   'is_local': False,
#   'name': 'Diana',
#   'popularity': 50,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ec93f2f35816b308eb0bc7fb4dd6c47730999a70?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2k6qpHJsrKCCyvsHv2cPqR'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4avsZn38cgMEmxmGdpb4lp'},
#    'href': 'https://api.spotify.com/v1/albums/4avsZn38cgMEmxmGdpb4lp',
#    'id': '4avsZn38cgMEmxmGdpb4lp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737f16eb646e4096177286ebc2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027f16eb646e4096177286ebc2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517f16eb646e4096177286ebc2',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Paul Anka Sings His Big 15 (Remastered)',
#    'release_date': '1959-01-02',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4avsZn38cgMEmxmGdpb4lp'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 161533,
#   'explicit': False,
#   'external_ids': {'isrc': 'US73K0300014'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1mdfrHeZzxjz0FJ4BKRuxS'},
#   'href': 'https://api.spotify.com/v1/tracks/1mdfrHeZzxjz0FJ4BKRuxS',
#   'id': '1mdfrHeZzxjz0FJ4BKRuxS',
#   'is_local': False,
#   'name': 'Puppy Love - Remastered',
#   'popularity': 46,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e6b1c600c1d6c9c4c5dd5344bb15f4a093e27517?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:1mdfrHeZzxjz0FJ4BKRuxS'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4avsZn38cgMEmxmGdpb4lp'},
#    'href': 'https://api.spotify.com/v1/albums/4avsZn38cgMEmxmGdpb4lp',
#    'id': '4avsZn38cgMEmxmGdpb4lp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737f16eb646e4096177286ebc2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027f16eb646e4096177286ebc2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517f16eb646e4096177286ebc2',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Paul Anka Sings His Big 15 (Remastered)',
#    'release_date': '1959-01-02',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4avsZn38cgMEmxmGdpb4lp'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 158906,
#   'explicit': False,
#   'external_ids': {'isrc': 'US73K0300002'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6YDDrg8llsRtAgLlIROzZc'},
#   'href': 'https://api.spotify.com/v1/tracks/6YDDrg8llsRtAgLlIROzZc',
#   'id': '6YDDrg8llsRtAgLlIROzZc',
#   'is_local': False,
#   'name': 'Put Your Head On My Shoulder - Remastered',
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dfc021b8e0e277a0d5ff7a3a5e37edbe7eb41050?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:6YDDrg8llsRtAgLlIROzZc'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0paOCYkZxIMIwfsxHHV2NV'},
#    'href': 'https://api.spotify.com/v1/albums/0paOCYkZxIMIwfsxHHV2NV',
#    'id': '0paOCYkZxIMIwfsxHHV2NV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732dbf778a3bbe1a68151ceb8f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022dbf778a3bbe1a68151ceb8f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512dbf778a3bbe1a68151ceb8f',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Paul Anka Sings His Big Ten, Vol. 2',
#    'release_date': '1992-01-17',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:0paOCYkZxIMIwfsxHHV2NV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 162373,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCRB0302618'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5kA88W2SwVZiPb9rEwnQj6'},
#   'href': 'https://api.spotify.com/v1/tracks/5kA88W2SwVZiPb9rEwnQj6',
#   'id': '5kA88W2SwVZiPb9rEwnQj6',
#   'is_local': False,
#   'name': 'Puppy Love',
#   'popularity': 45,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e5d62bfe6496b4ff8a39a3fb0285ac156976dc7c?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5kA88W2SwVZiPb9rEwnQj6'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3cdclv2AHxC4DTjlIujNeC'},
#    'href': 'https://api.spotify.com/v1/albums/3cdclv2AHxC4DTjlIujNeC',
#    'id': '3cdclv2AHxC4DTjlIujNeC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e7afa9599b308a962f843ed5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e7afa9599b308a962f843ed5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e7afa9599b308a962f843ed5',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Duets',
#    'release_date': '2013-04-05',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:3cdclv2AHxC4DTjlIujNeC'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GxkXlMwML1oSg5eLPiAz3'},
#     'href': 'https://api.spotify.com/v1/artists/1GxkXlMwML1oSg5eLPiAz3',
#     'id': '1GxkXlMwML1oSg5eLPiAz3',
#     'name': 'Michael Bublé',
#     'type': 'artist',
#     'uri': 'spotify:artist:1GxkXlMwML1oSg5eLPiAz3'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 250546,
#   'explicit': False,
#   'external_ids': {'isrc': 'USQX91300581'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/79tHp1cHwQG5f0AD6rP38l'},
#   'href': 'https://api.spotify.com/v1/tracks/79tHp1cHwQG5f0AD6rP38l',
#   'id': '79tHp1cHwQG5f0AD6rP38l',
#   'is_local': False,
#   'name': 'Pennies From Heaven (with Michael Bublé)',
#   'popularity': 48,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c7cd32c542fe8fdb8cd6626a2325e138577fa05b?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:79tHp1cHwQG5f0AD6rP38l'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4avsZn38cgMEmxmGdpb4lp'},
#    'href': 'https://api.spotify.com/v1/albums/4avsZn38cgMEmxmGdpb4lp',
#    'id': '4avsZn38cgMEmxmGdpb4lp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737f16eb646e4096177286ebc2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027f16eb646e4096177286ebc2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517f16eb646e4096177286ebc2',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Paul Anka Sings His Big 15 (Remastered)',
#    'release_date': '1959-01-02',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4avsZn38cgMEmxmGdpb4lp'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 147760,
#   'explicit': False,
#   'external_ids': {'isrc': 'US73K0300001'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0hjYuU2Z9jcKvOl39oUpeE'},
#   'href': 'https://api.spotify.com/v1/tracks/0hjYuU2Z9jcKvOl39oUpeE',
#   'id': '0hjYuU2Z9jcKvOl39oUpeE',
#   'is_local': False,
#   'name': 'Diana - Remastered',
#   'popularity': 47,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ec4608752c1f63235db135041c5de53e1600d2ce?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0hjYuU2Z9jcKvOl39oUpeE'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#      'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#      'id': '7ceUfdWq2t5nbatS6ollHh',
#      'name': 'Paul Anka',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0lbELQG6SSHy7LvBttGF2d'},
#    'href': 'https://api.spotify.com/v1/albums/0lbELQG6SSHy7LvBttGF2d',
#    'id': '0lbELQG6SSHy7LvBttGF2d',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27348deb845b097df5fe8ba1487',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0248deb845b097df5fe8ba1487',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485148deb845b097df5fe8ba1487',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Feelings',
#    'release_date': '1975',
#    'release_date_precision': 'year',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:0lbELQG6SSHy7LvBttGF2d'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ceUfdWq2t5nbatS6ollHh'},
#     'href': 'https://api.spotify.com/v1/artists/7ceUfdWq2t5nbatS6ollHh',
#     'id': '7ceUfdWq2t5nbatS6ollHh',
#     'name': 'Paul Anka',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ceUfdWq2t5nbatS6ollHh'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 195760,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEM38900155'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3AdX0KdVoMBqe82b19rWAU'},
#   'href': 'https://api.spotify.com/v1/tracks/3AdX0KdVoMBqe82b19rWAU',
#   'id': '3AdX0KdVoMBqe82b19rWAU',
#   'is_local': False,
#   'name': 'Times Of Your Life',
#   'popularity': 48,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3e1c8582f10ae0e719410c7ffe97eb6d63dae3c4?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:3AdX0KdVoMBqe82b19rWAU'}]

# %%
unique_billboard_tracks_df[unique_billboard_tracks_df['song']==song]
# Out:
# Empty DataFrame
# Columns: [song, artist, year, peak-rank, weeks-on-board, weeks-at-no1]
# Index: []

# %%
# # Import dependency for swifter module


# billboard_1960s['track_id'] = billboard_1960s[['song', 'artist']].swifter.apply(lambda row:get_track_id(row.song,row.artist),axis=1)
# billboard_1960s.to_csv(f'./Resources/billboard_1960s.csv')

# %%
# billboard_1970s['track_id'] = billboard_1970s[['song', 'artist']].swifter.apply(lambda row:get_track_id(row.song,row.artist),axis=1)
# billboard_1970s.to_csv(f'./Resources/billboard_1970s.csv')


billboard_1980s['track_id'] = billboard_1980s[['song', 'artist']].swifter.apply(lambda row:get_track_id(row.song,row.artist),axis=1)
billboard_1980s.to_csv(f'./Resources/billboard_1980s.csv')


billboard_1990s['track_id'] = billboard_1990s[['song', 'artist']].swifter.apply(lambda row:get_track_id(row.song,row.artist),axis=1)
billboard_1990s.to_csv(f'./Resources/billboard_1990s.csv')


billboard_2000s['track_id'] = billboard_2000s[['song', 'artist']].swifter.apply(lambda row:get_track_id(row.song,row.artist),axis=1)
billboard_2000s.to_csv(f'./Resources/billboard_2000s.csv')


billboard_2010s['track_id'] = billboard_2010s[['song', 'artist']].swifter.apply(lambda row:get_track_id(row.song,row.artist),axis=1)
billboard_2010s.to_csv(f'./Resources/billboard_2010s.csv')


billboard_2020s['track_id'] = billboard_2020s[['song', 'artist']].swifter.apply(lambda row:get_track_id(row.song,row.artist),axis=1)
billboard_2020s.to_csv(f'./Resources/billboard_2020s.csv')

# %%
df_1960s = pd.read_csv('./Resources/billboard_1960s.csv')

# %%
df_1960s.head()
# Out:
#    Unnamed: 0                                       song               artist  \
# 0          10             (1-2-3-4-5-6-7) Count The Days  Inez & Charlie Foxx
# 1          11  (A Ship Will Come) Ein Schiff Wird Kommen        Lale Anderson
# 2          13           (All Of A Sudden) My Heart Sings           Mel Carter
# 3          19                         (Baby) Hully Gully         The Olympics
# 4          29      (Come round Here) Im The One You Need         The Miracles
#
#    year  peak-rank  weeks-on-board  weeks-at-no1                track_id
# 0  1968         76               5           NaN  2aeZdQUwBksJPaRk1gaEAL
# 1  1961         88               4           NaN                     NaN
# 2  1965         38               7           NaN  6x5BiQwNlbtisITsEHa8Eu
# 3  1960         72               7           NaN  2CkbNJooPxUsHG4gFXKhxa
# 4  1966         17               9           NaN  5YvokzRkNONpj5c0TIqTjQ

# %%
# df_1960s[df_1960s['track_id']]


null_rows = df_1960s[df_1960s['track_id'].isnull()]

null_rows[null_rows['song'].str.contains("\?")]
# null_rows
# Out:
#       Unnamed: 0                                song  \
# 500         2042          Are You Lonesome To-night?
# 501         2043          Are You Lonesome To-night?
# 1408        6599      Did You Have A Happy Birthday?
# 1469        6941      Does He Mean That Much To You?
# 7236       33608                  What Would You Do?
# 7333       34116  While Youre Out Looking For Sugar?
# 7363       34269              Who Stole The Keeshka?
# 7374       34320       Whos Been Sleeping In My Bed?
# 7388       34378               Why Did You Leave Me?
#
#                                   artist  year  peak-rank  weeks-on-board  \
# 500   Elvis Presley With The Jordanaires  1960          1               7
# 501   Elvis Presley With The Jordanaires  1961          1              16
# 1408                           Paul Anka  1963         89               3
# 1469                         Eddy Arnold  1962         98               1
# 7236                          Jim Reeves  1961         73               5
# 7333                      The Honey Cone  1969         62               8
# 7363                     The Matys Bros.  1963         55               9
# 7374                         Linda Scott  1964        100               1
# 7388                       Vince Edwards  1962         68               6
#
#       weeks-at-no1 track_id
# 500            NaN      NaN
# 501            NaN      NaN
# 1408           NaN      NaN
# 1469           NaN      NaN
# 7236           NaN      NaN
# 7333           NaN      NaN
# 7363           NaN      NaN
# 7374           NaN      NaN
# 7388           NaN      NaN

# %%
df_1960s.drop_duplicates(['artist', 'song'])
# Out:
#       Unnamed: 0                                       song  \
# 0             10             (1-2-3-4-5-6-7) Count The Days
# 1             11  (A Ship Will Come) Ein Schiff Wird Kommen
# 2             13           (All Of A Sudden) My Heart Sings
# 3             19                         (Baby) Hully Gully
# 4             29      (Come round Here) Im The One You Need
# ...          ...                                        ...
# 7785       36028                                  Zero-Zero
# 7786       36030         Zing! Went The Strings Of My Heart
# 7787       36031                                   Zip Code
# 7788       36032                          Zip-A-Dee Doo-Dah
# 7790       36039                            Zorba The Greek
#
#                                artist  year  peak-rank  weeks-on-board  \
# 0                 Inez & Charlie Foxx  1968         76               5
# 1                       Lale Anderson  1961         88               4
# 2                          Mel Carter  1965         38               7
# 3                        The Olympics  1960         72               7
# 4                        The Miracles  1966         17               9
# ...                               ...   ...        ...             ...
# 7785                    Lawrence Welk  1962         98               1
# 7786                        The Furys  1963         92               2
# 7787               The Five Americans  1967         36               7
# 7788   Bob B. Soxx And The Blue Jeans  1962          9               7
# 7790  Herb Alpert & The Tijuana Brass  1965         82               1
#
#       weeks-at-no1                track_id
# 0              NaN  2aeZdQUwBksJPaRk1gaEAL
# 1              NaN                     NaN
# 2              NaN  6x5BiQwNlbtisITsEHa8Eu
# 3              NaN  2CkbNJooPxUsHG4gFXKhxa
# 4              NaN  5YvokzRkNONpj5c0TIqTjQ
# ...            ...                     ...
# 7785           NaN  5SUpO1bYMqXn2sjZiFXFI9
# 7786           NaN                     NaN
# 7787           NaN  1bdtY3SGI196r2LF0Dd6Oa
# 7788           NaN  477feyuGo8JUehyr1GXlVo
# 7790           NaN  5XAcKqknLkmAsnbDeJJxeN
#
# [6954 rows x 8 columns]
