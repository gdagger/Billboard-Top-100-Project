# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Resources/charts.csv')
df
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
cid = '1faf0948278a495a8995255521311153'
secret = 'd3f7c65793904be29142740ebaa6c168'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager
=
client_credentials_manager)

# %%
def get_track_uri(song_title, artist):
    searchResults = sp.search(q=f"artist:{artist} track:{song_title}", type="track")

    get_track_uri.counter += 1
    print(get_track_uri.counter)
    # success = 0
    # fail = 0
    # uris = []
    try:
        # success += 1
        # print(f"{success/(success+fail)}% success")
        return searchResults['tracks']['items'][0]['uri']
    except:
        # fail += 1
        # print(f"{fail/(success+fail)}% Failure")
        print('URI not found')
    # for track in searchResults['tracks']['items']:
    #     uri = track['uri']
    #     uris.append(uri)
    # return uris

get_track_uri.counter = 0

# %%
# df['track_uri'] = df.apply (lambda row: get_track_uri(row['song'], row['artist']), axis=1)

# %%
np.vectorize(get_track_uri)(df['song'], df['artist'])
# Out:
# 1
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/f5/fmwr4j4s4gv2xp3_q6xpt02w0000gn/T/ipykernel_63484/237284863.py in get_track_uri(song_title, artist)
#       9     try:
# ---> 10         success += 1
#      11         print(f"{success/(success+fail)}% success")
#
# UnboundLocalError: local variable 'success' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/f5/fmwr4j4s4gv2xp3_q6xpt02w0000gn/T/ipykernel_63484/2852335183.py in <module>
# ----> 1 np.vectorize(get_track_uri)(df['song'], df['artist'])
#
# ~/Downloads/anaconda3/envs/mlenv/lib/python3.7/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2161             vargs.extend([kwargs[_n] for _n in names])
#    2162
# ...
